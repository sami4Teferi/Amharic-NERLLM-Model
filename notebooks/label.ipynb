# %%
# import necessarry libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os 
import sys

# %%
sys.path.append(os.path.abspath(os.path.join('..')))
# importing modules from scripts
import scripts.labeling as l

# %%
df = pd.read_csv('../data/cleaned_data.csv')
df
# Out:
#      Unnamed: 0   Channel Title Channel Username    ID  \
# 0             0          ምርጥ ዕቃ        @MerttEka  8476
# 1             1          ምርጥ ዕቃ        @MerttEka  8475
# 2             2          ምርጥ ዕቃ        @MerttEka  8474
# 3             5          ምርጥ ዕቃ        @MerttEka  8470
# 4             6          ምርጥ ዕቃ        @MerttEka  8469
# ..          ...             ...              ...   ...
# 650        1278  Zemen Express®    @ZemenExpress  6592
# 651        1280  Zemen Express®    @ZemenExpress  6590
# 652        1281  Zemen Express®    @ZemenExpress  6589
# 653        1282  Zemen Express®    @ZemenExpress  6588
# 654        1283  Zemen Express®    @ZemenExpress  6587
#
#                                                Message  \
# 0        \n\n የWC መፀዳጃ መቀመጫ መሸፈኛ ፕላስቲክ\n የህዝብ መፀዳጃ ...
# 1                     \n\n  ./@\n  ./ \n\nለወዳጆችዎ  ያድርጉ
# 2        \n\n የልጆች  የቤት ውስጥ መጫወቻ ድንኳን\nበቀላሉ የሚዘረጋ እ...
# 3      \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n   ከማይዝግ ብረት የተሰራ\n የ...
# 4      \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n ከ 120°-150° ሙቀት ይቋቋማ...
# ..                                                 ...
# 650  ................................\n\n በረፍት ቀንዎ ...
# 651  ...................................\n\n   \n\n...
# 652  ...................................\n\n   \n\n...
# 653   ...................................\n\n     \...
# 654   ...................................\n\n     \...
#
#                           Date                     Media Path
# 0    2025-06-22 13:28:35+00:00                            NaN
# 1    2025-06-21 13:05:00+00:00                            NaN
# 2    2025-06-21 11:34:07+00:00      photos\@MerttEka_8474.jpg
# 3    2025-06-21 07:36:45+00:00      photos\@MerttEka_8470.jpg
# 4    2025-06-21 07:34:20+00:00      photos\@MerttEka_8469.jpg
# ..                         ...                            ...
# 650  2025-04-26 14:57:10+00:00  photos\@ZemenExpress_6592.jpg
# 651  2025-04-26 13:30:15+00:00  photos\@ZemenExpress_6590.jpg
# 652  2025-04-26 13:29:20+00:00                            NaN
# 653  2025-04-26 12:06:08+00:00  photos\@ZemenExpress_6588.jpg
# 654  2025-04-26 12:05:04+00:00                            NaN
#
# [655 rows x 7 columns]

# %%
df.drop(columns='Unnamed: 0')
# Out:
#       Channel Title Channel Username    ID  \
# 0            ምርጥ ዕቃ        @MerttEka  8476
# 1            ምርጥ ዕቃ        @MerttEka  8475
# 2            ምርጥ ዕቃ        @MerttEka  8474
# 3            ምርጥ ዕቃ        @MerttEka  8470
# 4            ምርጥ ዕቃ        @MerttEka  8469
# ..              ...              ...   ...
# 650  Zemen Express®    @ZemenExpress  6592
# 651  Zemen Express®    @ZemenExpress  6590
# 652  Zemen Express®    @ZemenExpress  6589
# 653  Zemen Express®    @ZemenExpress  6588
# 654  Zemen Express®    @ZemenExpress  6587
#
#                                                Message  \
# 0        \n\n የWC መፀዳጃ መቀመጫ መሸፈኛ ፕላስቲክ\n የህዝብ መፀዳጃ ...
# 1                     \n\n  ./@\n  ./ \n\nለወዳጆችዎ  ያድርጉ
# 2        \n\n የልጆች  የቤት ውስጥ መጫወቻ ድንኳን\nበቀላሉ የሚዘረጋ እ...
# 3      \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n   ከማይዝግ ብረት የተሰራ\n የ...
# 4      \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n ከ 120°-150° ሙቀት ይቋቋማ...
# ..                                                 ...
# 650  ................................\n\n በረፍት ቀንዎ ...
# 651  ...................................\n\n   \n\n...
# 652  ...................................\n\n   \n\n...
# 653   ...................................\n\n     \...
# 654   ...................................\n\n     \...
#
#                           Date                     Media Path
# 0    2025-06-22 13:28:35+00:00                            NaN
# 1    2025-06-21 13:05:00+00:00                            NaN
# 2    2025-06-21 11:34:07+00:00      photos\@MerttEka_8474.jpg
# 3    2025-06-21 07:36:45+00:00      photos\@MerttEka_8470.jpg
# 4    2025-06-21 07:34:20+00:00      photos\@MerttEka_8469.jpg
# ..                         ...                            ...
# 650  2025-04-26 14:57:10+00:00  photos\@ZemenExpress_6592.jpg
# 651  2025-04-26 13:30:15+00:00  photos\@ZemenExpress_6590.jpg
# 652  2025-04-26 13:29:20+00:00                            NaN
# 653  2025-04-26 12:06:08+00:00  photos\@ZemenExpress_6588.jpg
# 654  2025-04-26 12:05:04+00:00                            NaN
#
# [655 rows x 6 columns]

# %%
df = df.dropna(subset=['Message'])
message_cleaned = df['Message'].isnull().sum()
print(f"Numer of NAN values in Message columns is {message_cleaned}")
# Out:
# Numer of NAN values in Message columns is 0

# %%
# Apply the updated function to the non-null messages
df['Labeled_Message'] = df['Message'].apply(l.label_message_utf8_with_birr)

# Display the updated DataFrame
df.head()
# Out:
#    Unnamed: 0 Channel Title Channel Username    ID  \
# 0           0        ምርጥ ዕቃ        @MerttEka  8476
# 1           1        ምርጥ ዕቃ        @MerttEka  8475
# 2           2        ምርጥ ዕቃ        @MerttEka  8474
# 3           5        ምርጥ ዕቃ        @MerttEka  8470
# 4           6        ምርጥ ዕቃ        @MerttEka  8469
#
#                                              Message  \
# 0      \n\n የWC መፀዳጃ መቀመጫ መሸፈኛ ፕላስቲክ\n የህዝብ መፀዳጃ ...
# 1                   \n\n  ./@\n  ./ \n\nለወዳጆችዎ  ያድርጉ
# 2      \n\n የልጆች  የቤት ውስጥ መጫወቻ ድንኳን\nበቀላሉ የሚዘረጋ እ...
# 3    \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n   ከማይዝግ ብረት የተሰራ\n የ...
# 4    \n\n የድንች/ካሮት/ሩዝ መፍጪያ\n ከ 120°-150° ሙቀት ይቋቋማ...
#
#                         Date                 Media Path  \
# 0  2025-06-22 13:28:35+00:00                        NaN
# 1  2025-06-21 13:05:00+00:00                        NaN
# 2  2025-06-21 11:34:07+00:00  photos\@MerttEka_8474.jpg
# 3  2025-06-21 07:36:45+00:00  photos\@MerttEka_8470.jpg
# 4  2025-06-21 07:34:20+00:00  photos\@MerttEka_8469.jpg
#
#                                      Labeled_Message
# 0  የWC O\nመፀዳጃ O\nመቀመጫ O\nመሸፈኛ O\nፕላስቲክ O\nየህዝብ O...
# 1                            ./@ O\nለወዳጆችዎ O\nያድርጉ O
# 2  የልጆች O\nየቤት O\nውስጥ I-PRODUCT\nመጫወቻ I-PRODUCT\n...
# 3  የድንች/ካሮት/ሩዝ I-PRODUCT\nመፍጪያ B-PRODUCT\nከማይዝግ O...
# 4  የድንች/ካሮት/ሩዝ I-PRODUCT\nመፍጪያ B-PRODUCT\nከ O\n12...

# %%
# Save the updated labeled dataset to a file in CoNLL format
labeled_data_birr_path = '../data/labeled_telegram_product_price_location.txt-'
with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
    for index, row in df.iterrows():
        f.write(f"{row['Labeled_Message']}\n\n")
